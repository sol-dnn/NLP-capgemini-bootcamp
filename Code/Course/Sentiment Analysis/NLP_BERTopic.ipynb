# %% [markdown]
# # Transformer-based NLP topic modeling using the Python package BERTopic!!

# %% [markdown]
# # Intro

# %% [markdown]
# BERTopic is a topic modeling python library that uses the combination of transformer embeddings and clustering model algorithms to identify topics in NLP (Natual Language Processing). In this notebook, we will talk about:
# * How transformers, c-TF-IDF, and clustering models are used behind the BERTopic?
# * How to extract and interpret topics from the topic modeling results?
# * How to make predictions using topic modeling?
# * How to save and load a BERTopic topic model?

# %% [markdown]
# # BERTopic Model Algorithms

# %% [markdown]
# In step 0, we will talk about the algorithms behind the BERTopic model.
# * **Documents Embedding**: Firstly, we need to get the embeddings for all the documents. Embeddings are the vector representation of the documents.
#  * BERTopic uses the English version of the `sentence_transformers` by default to get document embeddings.
#  * If there are multiple languages in the document, we can use `BERTopic(language="multilingual")` to support the topic modeling of over 50 languages.
#  * BERTopic also supports the pre-trained models from other python packages such as hugging face and flair.
# * **Dimension Reduction and Documents Clustering**: After the text documents have been transformed into embeddings, the next step is to run a clustering model on the embedded documents. Because the embedding vectors usually have very high dimensions, dimension reduction techniques are used to reduce the dimensionalities.
#  * The default algorithm for dimension reduction is UMAP (Uniform Manifold Approximation & Projection). Compared with other dimension reduction techniques such as PCA (Principle Component Analysis), UMAP maintains the data's local and global structure when reducing the dimensionality, which is important for representing the semantics of the text data. BERTopic provides the option of using other dimensionality reduction techniques by changing the `umap_model` value in the `BERTopic` method.
#  * The default algorithm for clustering is HDBSCAN. HDBSCAN is a density-based clustering model. It identifies the number of clustering automatically, and does not require specifying the number of clusters beforehand like most of the clustering models.
# * **Topic Representation**: After assigning each document in the corpus into a cluster, the next step is to get the topic representation using a class-based TF-IDF called c-TF-IDF. The top words with the highest c-TF-IDF scores are selected to represent each topic.
#  * c-TF-IDF is similar to TF-IDF in that it measures the term importance by term frequencies while taking into account the whole corpus (all the text data for the analysis).
#  * c-TF-IDF is different from TF-IDF in that the term frequency level is different. In the regular TF-IDF, TF measures the term frequency in each document. While in the c-TF-IDF, TF measures the term frequency in each cluster, and each cluster includes many documents.
# * **Maximal Marginal Relevance (MMR)** (optional): After extracting the most important terms describing each cluster, there is an optional step to optimize the terms using Maximal Marginal Relevance (MMR). Maximal Marginal Relevance (MMR) has two benefits:
#  * The first benefit is to increase the coherence among the terms for the same topic and remove irrelevant terms.
#  * The second benefit is to increase the topic representation by removing synonyms and variations of the same words.

# %% [markdown]
# # Install And Import Python Libraries

# %% [markdown]
# In step 1, we will install and import python libraries.
#
# Firstly, let's import `bertopic`.

# %%
# Install bertopic
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.25.2)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 21.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.2)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.37.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039281 sha256=8e62acb5fffb46380c05e117cf5e43ab83a385ca083a91db77ea2e8898073e29
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=279a8d678757bb7f185116e4f755a7d18d123bac98972088e899ede1ab0ff62b
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.4.0 umap-learn-0.5.5

# %% [markdown]
# Secondly, import necessary packages

# %%
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer

import pandas as pd
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Understand data

# %% [markdown]
# The second step is to download and read the dataset.

# %% [markdown]
# * `drive.mount` is used to mount to the Google drive so the colab notebook can access the data on the Google drive.
# * `os.chdir` is used to change the default directory on Google drive. I set the default directory to the folder where the review dataset is saved.
# * `!pwd` is used to print the current working directory.
#
# Please check out [Google Colab Tutorial for Beginners](https://medium.com/towards-artificial-intelligence/google-colab-tutorial-for-beginners-834595494d44) for details about using Google Colab for data science projects.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change directory
import os
os.chdir("drive/My Drive/Colab Notebooks")

# Print out the current directory
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# Now let's read the data `reviews_cleaned.parquet` into a `pandas` dataframe and see what the dataset looks like.

# %%
# Read in data
data = pd.read_parquet("/content/reviews_cleaned.parquet")

# %%
data.head()
# Out:
#    Unnamed: 0  page                                              titre  \
# 0           0     1                           Aucun soucis particulier
# 1           1     1            Engie facture a ses clients des sommes…
# 2           2     1   Facturation sur consommation d'un autre logement
# 3           3     1                un service client ou il est dur de…
# 4           4     1  Client d'ENGIE depuis longtemps toujours satis...
#
#                                             verbatim               date  note  \
# 0  Je paie ma facture tous les deux mois en fonct...   Il y a 17 heures     4
# 1  Engie facture a ses clients des sommes exorbit...     Il y a un jour     1
# 2  Ils me facturent sur le pdl du logement au des...     ll y a 3 jours     1
# 3  un service client ou il est dur de comprendre ...     ll y a 3 jours     1
# 4  Excellente expérience avec ENGIE et une interl...  Il y a 24 minutes     5
#
#                                              reponse  \
# 0                                               None
# 1  Bonjour Julien Blanco,\n\nPour des raisons de ...
# 2  Bonjour BlooDz,\n\nPour des raisons de confide...
# 3  Bonjour Ricanto77,\nPour des raisons de confid...
# 4                                               None
#
#                           date_experience  \
# 0  Date de l'expérience: 01 décembre 2022
# 1  Date de l'expérience: 26 novembre 2022
# 2  Date de l'expérience: 29 novembre 2022
# 3  Date de l'expérience: 29 novembre 2022
# 4  Date de l'expérience: 01 décembre 2022
#
#                                  fournisseur      source  \
# 0  https://fr.trustpilot.com/review/engie.fr  trustpilot
# 1  https://fr.trustpilot.com/review/engie.fr  trustpilot
# 2  https://fr.trustpilot.com/review/engie.fr  trustpilot
# 3  https://fr.trustpilot.com/review/engie.fr  trustpilot
# 4  https://fr.trustpilot.com/review/engie.fr  trustpilot
#
#                                           clean_verb  \
# 0  je paie ma facture tous les deux mois en fonct...
# 1  engie facture a ses clients des sommes exorbit...
# 2  ils me facturent sur le pdl du logement au des...
# 3  un service client ou il est dur de comprendre ...
# 4  excellente expérience avec engie et une interl...
#
#                                               tokens  \
# 0  [[je, ], [paie, ], [ma, ], [facture, ], [tous,...
# 1  [[engie, ], [facture, ], [a, ], [ses, ], [clie...
# 2  [[ils, ], [me, ], [facturent, ], [sur, ], [le,...
# 3  [[un, ], [service, ], [client, ], [ou, ], [il,...
# 4  [[excellente, ], [expérience, ], [avec, ], [en...
#
#                                           tokens_lem  \
# 0  [[je, ], [pai, ], [ma, ], [factur, ], [tous, ]...
# 1  [[engi, ], [factur, ], [a, ], [se, ], [client,...
# 2  [[il, ], [me, ], [facturent, ], [sur, ], [le, ...
# 3  [[un, ], [servic, ], [client, ], [ou, ], [il, ...
# 4  [[excellent, ], [expérient, ], [avec, ], [engi...
#
#                                     tokens_processed  \
# 0  [paie, facture, mois, fonction, consommation, ...
# 1  [engie, facture, clients, exorbitants, engie, ...
# 2  [facturent, pdl, logement, disant, faute, jama...
# 3  [service, client, dur, comprendre, langue, uti...
# 4  [excellente, expérience, engie, interlocutrice...
#
#                                 tokens_lem_processed
# 0  [pai, factur, mois, fonction, consomm, exact, ...
# 1  [engi, factur, client, somm, exorbit, engi, fa...
# 2  [facturent, pdl, log, dis, faut, jam, pris, fa...
# 3  [servic, client, dur, comprendr, langu, utilis...
# 4  [excellent, expérient, engi, interlocutric, so...

# %% [markdown]
# # Embeddings

# %%
# Initiate Embedding model using SentenceTransformer use "paraphrase-multilingual-MiniLM-L12-v2"

model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
#embeddings = model.encode(data)
#print(embeddings)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# BERTopic model by default produces different results each time because of the stochasticity inherited from UMAP.
#
# To get reproducible topics, we need to pass a value to the `random_state` parameter in the `UMAP` method.
# * `n_neighbors=15` means that the local neighborhood size for UMAP is 15. This is the parameter that controls the local versus global structure in data.
#  * A low value forces UMAP to focus more on local structure, and may lose insights into the big picture.
#  * A high value pushes UMAP to look at broader neighborhood, and may lose details on local structure.
#  * The default `n_neighbors` values for UMAP is 15.
# * `n_components=5` indicates that the target dimension from UMAP is 5. This is the dimension of data that will be passed into the clustering model.
# * `min_dist` controls how tightly UMAP is allowed to pack points together. It's the minimum distance between points in the low dimensional space.
#  * Small values of `min_dist` result in clumpier embeddings, which is good for clustering. Since our goal of dimension reduction is to build clustering models, we set `min_dist` to 0.
#  * Large values of `min_dist` prevent UMAP from packing points together and preserves the broad structure of data.
# * `metric='cosine'` indicates that we will use cosine to measure the distance.
# * `random_state` sets a random seed to make the UMAP results reproducible.

# %%
# Instanciate UMAP
umap_reducer = UMAP(n_neighbors=15, min_dist=0, random_state =42, n_components=5, metric='cosine')

# %% [markdown]
# # Clustering

# %%
# Instanciate HDBSCAN
clusterer = HDBSCAN()

# %% [markdown]
# # Vectorizers

# %%
# Instanciate a CountVectorizer
vectorizer = CountVectorizer()

# %% [markdown]
# # cTF-IDF
# In BERTopic, in order to get an accurate representation of the topics from our bag-of-words matrix, TF-IDF was adjusted to work on a cluster/categorical/topic level instead of a document level. This adjusted TF-IDF representation is called c-TF-IDF and takes into account what makes the documents in one cluster different from documents in another cluster:

# %%
# Instanciate a ClassTfidf
ctf_idf = ClassTfidfTransformer()

# %% [markdown]
# # Topic Representation
#
# After having generated our topics with c-TF-IDF, we might want to do some fine-tuning based on the semantic relationship between keywords/keyphrases and the set of documents in each topic. Although we can use a centroid-based technique for this, it can be costly and does not take the structure of a cluster into account. Instead, we leverage c-TF-IDF to create a set of representative documents per topic and use those as our updated topic embedding. Then, we calculate the similarity between candidate keywords and the topic embedding using the same embedding model that embedded the documents.

# %%
# Instanciate a keyBERTInspired
# KeyBERT is a minimal and easy-to-use method for keyword extraction with BERT embeddings

kw_model = KeyBERTInspired()

# %% [markdown]
# # Put All together

# %% [markdown]
# Finally, we pass the processed review documents to the topic model and saved the results for topics and topic probabilities.
#
# The values in topics represents the topic each document is assigned to.
# The values in probabilities represents the probability of a document belongs to each of the topics

# %%
# Instanciate a BERTopic class with all components above and fit to documents
bertopic = BERTopic(
    embedding_model=model,
    umap_model=umap_reducer,
    hdbscan_model=clusterer,
    vectorizer_model =vectorizer,
    ctfidf_model = ctf_idf,
    representation_model = kw_model,
    )

# %% [markdown]
# # Analyse Topics

# %%
topics, probabilities = bertopic.fit_transform(data["verbatim"])

# %%
# Get the list of topics
topics = bertopic.get_topics()
print(topics)

# Each topic is represented as a pair of (word, weight)
# Let's print the topics
for topic_num, topic in topics.items():
    print(f"Topic {topic_num}: ", end="")
    words = ", ".join([word for word, _ in topic])
    print(words)
# Out:
# {-1: [('payer', 0.45674336), ('factures', 0.4250915), ('facture', 0.40951094), ('contrat', 0.40152055), ('fournisseur', 0.33512533), ('électricité', 0.30681598), ('compte', 0.30537814), ('demande', 0.30454472), ('depuis', 0.29089668), ('service', 0.28256637)], 0: [('technicienne', 0.79316366), ('techniciens', 0.75618535), ('technicien', 0.7526088), ('professionnels', 0.69989526), ('professionnel', 0.66280687), ('compétent', 0.5814539), ('compétents', 0.57771164), ('métier', 0.55272746), ('professionnalisme', 0.5466609), ('competent', 0.5377156)], 1: [('téléphonique', 0.8161819), ('telephone', 0.8077973), ('téléphoniques', 0.80605483), ('téléphone', 0.804651), ('contact', 0.68294376), ('telephonique', 0.6736375), ('communication', 0.6560931), ('accueil', 0.62653685), ('accueillant', 0.6212888), ('appel', 0.61798394)], 2: [('bien', 0.9551678), ('parfait', 0.91042167), ('fait', 0.76099765), ('très', 0.7358353), ('', 0.6872295), ('', 0.6872295), ('', 0.6872295), ('', 0.6872295), ('', 0.6872295), ('', 0.6872295)], 3: [('chaudière', 0.64151514), ('chaudières', 0.6392466), ('chauffage', 0.6266941), ('thermostat', 0.59199667), ('pompe', 0.5334375), ('chaleur', 0.52341616), ('température', 0.44856152), ('plombier', 0.43366203), ('cheminée', 0.428909), ('chaude', 0.40453285)], 4: [('engie', 0.51482064), ('eni', 0.44679776), ('enedis', 0.3112128), ('fournisseur', 0.2895925), ('contrat', 0.28148353), ('payer', 0.277302), ('demande', 0.27342135), ('compteurs', 0.24953088), ('remboursement', 0.2464894), ('facture', 0.24463075)], 5: [('bien', 0.99435997), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421), ('', 0.8023421)], 6: [('paiement', 0.6076504), ('remboursement', 0.6000076), ('payer', 0.5507276), ('remboursé', 0.52847517), ('rembourser', 0.5095747), ('chèques', 0.5073413), ('factures', 0.5060278), ('bancaire', 0.5056955), ('banque', 0.49763542), ('payé', 0.48001724)], 7: [('green', 0.75242025), ('greenpeace', 0.6959264), ('greenwashing', 0.67101747), ('énergies', 0.638722), ('énergie', 0.62202704), ('vert', 0.56185514), ('électricités', 0.52960277), ('électricité', 0.529533), ('electricité', 0.51876026), ('pouvoir', 0.4574021)], 8: [('chaudière', 0.5949626), ('chaudières', 0.5691062), ('techniciens', 0.55194545), ('technicien', 0.5451615), ('pompe', 0.5124922), ('chauffage', 0.48427597), ('compétent', 0.4397074), ('entretient', 0.42695552), ('professionnel', 0.42321235), ('efficace', 0.39525443)], 9: [('escroquerie', 0.5105727), ('malhonnêteté', 0.4967055), ('incompétents', 0.4892326), ('incompétence', 0.47387117), ('malhonnêtes', 0.46357054), ('imbéciles', 0.4463123), ('incompétent', 0.44097874), ('prévenir', 0.43654728), ('consommateurs', 0.4107492), ('honteux', 0.3972081)], 10: [('simple', 0.90088177), ('simplicite', 0.8547666), ('fácile', 0.8544773), ('facile', 0.84221125), ('simplicité', 0.8397696), ('simples', 0.8365463), ('straightforward', 0.8340705), ('faciles', 0.81044316), ('facilité', 0.72391343), ('facilités', 0.6435164)], 11: [('contrat', 0.53933626), ('contrats', 0.52079463), ('engagé', 0.50428593), ('remerciements', 0.4793927), ('collaboratrice', 0.4685737), ('remercie', 0.46553183), ('recommanderai', 0.42692253), ('contactée', 0.41821092), ('souscrire', 0.41306603), ('satisfaite', 0.41151914)], 12: [('solaires', 0.78530943), ('solaire', 0.7647262), ('photovoltaïques', 0.57549465), ('professionnel', 0.3585605), ('conseiller', 0.3546716), ('visite', 0.34057018), ('précises', 0.3131961), ('présentation', 0.30524707), ('claires', 0.30051818), ('représentant', 0.29857364)], 13: [('téléphonique', 0.7085916), ('téléphoniques', 0.70723367), ('téléphone', 0.69862056), ('téléconseiller', 0.69607776), ('telephone', 0.693012), ('telephonique', 0.67243457), ('communication', 0.6482748), ('call', 0.5663809), ('difficile', 0.5117506), ('difficulté', 0.495788)], 14: [('factures', 0.60752165), ('prélèvements', 0.5356625), ('financière', 0.5103635), ('p ...
# Topic -1: payer, factures, facture, contrat, fournisseur, électricité, compte, demande, depuis, service
# Topic 0: technicienne, techniciens, technicien, professionnels, professionnel, compétent, compétents, métier, professionnalisme, competent
# Topic 1: téléphonique, telephone, téléphoniques, téléphone, contact, telephonique, communication, accueil, accueillant, appel
# Topic 2: bien, parfait, fait, très, , , , , ,
# Topic 3: chaudière, chaudières, chauffage, thermostat, pompe, chaleur, température, plombier, cheminée, chaude
# Topic 4: engie, eni, enedis, fournisseur, contrat, payer, demande, compteurs, remboursement, facture
# Topic 5: bien, , , , , , , , ,
# Topic 6: paiement, remboursement, payer, remboursé, rembourser, chèques, factures, bancaire, banque, payé
# Topic 7: green, greenpeace, greenwashing, énergies, énergie, vert, électricités, électricité, electricité, pouvoir
# Topic 8: chaudière, chaudières, techniciens, technicien, pompe, chauffage, compétent, entretient, professionnel, efficace
# Topic 9: escroquerie, malhonnêteté, incompétents, incompétence, malhonnêtes, imbéciles, incompétent, prévenir, consommateurs, honteux
# Topic 10: simple, simplicite, fácile, facile, simplicité, simples, straightforward, faciles, facilité, facilités
# Topic 11: contrat, contrats, engagé, remerciements, collaboratrice, remercie, recommanderai, contactée, souscrire, satisfaite
# Topic 12: solaires, solaire, photovoltaïques, professionnel, conseiller, visite, précises, présentation, claires, représentant
# Topic 13: téléphonique, téléphoniques, téléphone, téléconseiller, telephone, telephonique, communication, call, difficile, difficulté
# Topic 14: factures, prélèvements, financière, payer, paye, facture, montant, payais, payé, consommation
# Topic 15: edf, facture, banque, contrat, eur, compte, envoyé, résilié, clients, entreprise
# Topic 16: edf, enr, compétent, professionnel, conseillerait, conseiller, recommanderais, fiable, attachante, appréciées
# Topic 17: ras, le, sympa, , , , , , ,
# Topic 18: convient, apprécie, parfaitement, ilek, recommande, excellent, chez, ami, depuis, satisfaite
# Topic 19: recommandee, volonte, bonneconnaissance, founiseur, marre, efficacite, soutiens, parraigne, savamment, fairedes
# Topic 20: engie, satisfaits, satisfaite, satisfait, eni, remerciement, merci, agréables, chez, home
# Topic 21: facture, 104990331, 104643028, 104990890, 104498519, 105922279, 104588009, 103416687, code, 105121228
# Topic 22: ras, de, , , , , , , ,
# Topic 23: subscription, abonement, abonnement, abonnée, abonner, abonné, inscrire, cliente, souscrire, connection
# Topic 24: inscription, inscriptions, rapide, textes, rapidité, instants, ligne, signaler, détaillé, prise
# Topic 25: parfait, , , , , , , , ,
# Topic 26: qualité, service, avantageux, good, excellent, prix, marché, recommander, price, payeur
# Topic 27: attendrai, attendons, attente, espere, attendos, régleront, pourrons, maintenant, prochain, doit
# Topic 28: intervention, interventions, intervenant, intervenants, assistance, efficace, traitée, aides, conseils, efficacité
# Topic 29: personne, rien, écouter, écoute, voix, parle, insuffisante, injoignables, toute, bruit
# Topic 30: equipe, équipe, équipes, champions, formidables, formidable, sympathique, géniale, bonne, bravo
# Topic 31: bien, bon, super, franchement, vraiment, très, répondu, trés, ,
# Topic 32: commercial, annonces, commercialisée, commerciale, panneau, apprécié, agréable, bonne, super, sympathique
# Topic 33: super, superbe, , , , , , , ,
# Topic 34: tres, bien, est, ok, super, apli, , , ,
# Topic 35: amabilité, efficacité, eficacité, efficaces, efficace, qualite, compétences, satisfaisant, compétence, serviabilité
# Topic 36: conseiller, conseillere, conseillers, conseillère, écouter, conseillé, conseil, conseille, conseils, écoute
# Topic 37: 18h30, 12h30, 13h30, 10h30, 16h30, 17h30, 11h45, retard, heure, horaire
# Topic 38: satisfait, bien, rien, jamais, aucun, toujours, déjà, correct, depuis, tant
# Topic 39: incompétentes, service, incompétent, désagréable, désagreable, inacceptables, client, deplorable, imcomprehensible, défaillant
# Topic 40: satisfaits, satisfaite, satisfait, service, services, satisfaction, agréable, complétement, accueil, apprécions
# Topic 41: service, services, efficace, efficacité, compétent, fiable, opérationnel, professionnel, performant, administratif
# Topic 42: bien, bon, , , , , , , ,
# Topic 43: satisfait, très, vraiment, , , , , , ,
# Topic 44: éléctricité, energie, énergie, économiser, direct, profiter, réduction, mensualisation, profitez, bénéficiez
# Topic 45: électricité, renouvelables, fournisseur, fournisseurs, innovante, renouvelable, ilek, producteurs, énergies, durable
# Topic 46: puisque, vien, donc, attendons, maintenant, donnerais, inscrire, juste, pas, ne
# Topic 47: professionnel, très, , , , , , , ,
# Topic 48: web, site, facile, internet, net, faciles, facilement, facilité, simplicité, simple
# Topic 49: rapide, rapidement, rapidite, efficace, rapidité, efficaces, efficacité, compétent, satisfaisant, excellent
# Topic 50: efficace, efficaces, satisfaisant, efficacité, performante, performant, agreable, parfaitement, serviable, bonne
# Topic 51: tres, three, tre, 3emme, bonne, bon, bien, pendant, gentille, toutes
# Topic 52: concurrentiel, compétitivité, compétitif, concurrentiels, compétitifs, prix, marché, concurrence, abordables, rachètent
# Topic 53: fournisseur, fournisseurs, fourniteur, changer, changement, remboursée, changé, accessible, envoyer, gmail
# Topic 54: installé, instalation, installés, installion, installation, attente, attendons, attendrons, viendra, confirmera
# Topic 55: carburant, gaz, tarif, remboursera, année, inflation, 2021, total, permette, mois
# Topic 56: conseillé, conseiller, conseillère, compréhensibles, comprendre, écoute, expliquées, éclaircissements, rassurant, conseils
# Topic 57: profesionnel, professionnels, professionnel, professionnelle, personnel, , , , ,
# Topic 58: rapidement, rapide, rapidité, bonne, efficace, bien, vite, bon, parfait, agréable
# Topic 59: explications, explication, compréhensions, précisions, précises, explicatios, facile, merci, parfait, simples
# Topic 60: paiement, facturation, tarifs, mensuelle, bilan, date, juin, clients, 2022, reçu
# Topic 61: français, française, francaise, paris, marseille, english, langue, parlais, parlait, parle
# Topic 62: kwh, hp, kw, kilowattheure, prix, 3900kwh, tarif, 3800kwh, taxe, htt
# Topic 63: attentes, espoirs, espère, répondu, prévue, prestations, répond, répondre, prestation, souhaite
# Topic 64: bien, vite, et, , , , , , ,
# Topic 65: service, timely, services, efficace, efficaces, automatique, rapide, rapidement, rapidité, pratique
# Topic 66: rien, maintenant, pas, donc, négatif, aujourd, présent, dirais, espérant, dire
# Topic 67: paiement, payline, facturation, facture, bancaires, mensualisé, mail, argent, service, client
# Topic 68: longtemps, long, longue, longs, loin, longues, délai, attendu, attente, trop
# Topic 69: satisfaits, satisfaite, satisfait, parfait, extrêmement, ravi, totalement, entièrement, très,
# Topic 70: bien, bon, maintenant, actuellement, convient, déjà, ok, espérant, parfait, tôt
# Topic 71: gentille, dame, madame, gentil, agréable, femme, remerciez, merci, elle, accueillie
# Topic 72: profesionnel, professionnel, professionnels, compétent, compétente, professionnelle, professionnalisme, professionnalisation, competent, efficaces
# Topic 73: connection, accès, acceder, connections, connecter, internet, account, password, cannot, provider
# Topic 74: compétent, techniciens, professionnel, technicien, compétences, professionnelle, efficaces, efficace, intervention, interventions
# Topic 75: energie, énergie, prélèvements, payer, factures, montant, facture, 2020, consommation, 2019
# Topic 76: tarif, moins, alpiq, pris, réglementé, acheté, rien, erreur, dépassé, importe
# Topic 77: contacté, mail, contrat, contracté, informer, appeler, adresse, contactera, appel, conseillers
# Topic 78: énergies, energie, énergétique, énergie, fournisseur, abordable, qualité, appréciable, efficacement, service
# Topic 79: abonnement, facturation, payé, facture, électricité, contrat, consommation, électrique, mois, 18
# Topic 216: entreprise, entreprises, compagnie, entrepreneur, commerciaux, métier, société, professionnels, concurrentiel, importante
# Topic 217: tres, renseignemt, fait, pro, , , , , ,
# Topic 218: contract, contrat, signé, signature, signer, facturations, reçu, difficultés, consentement, escroc
# Topic 219: utilisation, facile, pratique, simple, consommation, accessible, par, accès, fonctionnelle, pour
# Topic 220: , , , , , , , , ,
# Topic 221: fournisseur, changer, distributeur, changé, offre, changement, change, précédent, acces, avance
# Topic 222: top, au, , , , , , , ,
# Topic 223: bien, bon, parfait, super, génial, satisfait, merci, va, ok, bravo
# Topic 224: jadore, de, avenant, , , , , , ,
# Topic 225: cher, peu, tarif, mais, moins, pas, très, pour, que, bien
# Topic 226: bien, très, , , , , , , ,
# Topic 227: site, web, internet, abonnement, service, services, excellente, excellent, societe, clientèle
# Topic 228: renseignements, informations, informatios, information, infos, pertinentes, accueil, enrichissantes, satisfaisantes, importante
# Topic 229: conseillere, conseiller, merci, agréable, bien, bon, excellente, excellent, pour, fournisdeur
# Topic 230: explications, explication, compréhensibles, compréhensible, clarté, compréhensives, détaillées, simples, et, precises
# Topic 231: facile, simple, facilité, efficace, rapide, rapidité, peu, parfait, merci, aimable
# Topic 232: incompréhension, malheureusement, puisque, négociation, néanmoins, compliquent, avons, étaient, proposées, complique
# Topic 233: super, génial, great, , , , , , ,
# Topic 234: satisfaite, satisfait, satisfaction, satisfai, pleine, très, , , ,
# Topic 235: efficacité, rapidité, rapide, dépannage, qualité, énergie, qualités, et, en, de
# Topic 236: client, clients, service, services, actif, réactivité, efficace, efficacité, performant, concurentiel
# Topic 237: professionnel, professionnels, respectait, parfait, super, bien, bravo, très, superbe, vrai
# Topic 238: merguez, fuyez, éditée, prévoyez, tu, depuit, ieme, décidez, débranche, dépassent
# Topic 239: bonne, super, bien, très, bravo, vraiment, avec, grosse, prise, tout
# Topic 240: service, services, excellents, excellent, parfait, merci, bon, disponible, disponibilité, pour
# Topic 241: contradiction, tromperie, malhonnêtes, incompétents, malhonnête, incompétente, incompétence, incompétent, menteurs, incompétant
# Topic 242: service, clients, clientel, fournisseur, client, recommander, sympathique, recommande, agréable, bien
# Topic 243: correct, correcte, , , , , , , ,
# Topic 244: bien, parfaitement, super, sincèrement, très, , , , ,
# Topic 245: professionnalisme, professionalisme, competences, professionnel, professionnelle, compétences, compétent, compétence, efficacité, personnels
# Topic 246: rapide, super, vite, très, bien, cela, aété, vraiment, est,
# Topic 247: écoutent, écoute, donc, très, répondre, je, notre, pour, après, est
# Topic 248: professionnel, professionalisme, professionnels, professionel, écoute, personnel, maîtrise, sujet, salarié, et
# Topic 249: facile, simplicité, merci, simples, souscrire, simple, recommande, souscrit, inscription, rassurant
# Topic 250: services, service, serviable, qualité, efficace, recommande, consommation, satisfaisant, conseil, aides
# Topic 251: téléphonique, téléphone, téléphoner, appeler, communicant, numéro, internet, adresse, assistante, interrompu
# Topic 252: internet, réseaux, tel, information, facile, et, en, ai, est, simple
# Topic 253: maintenant, rien, depuis, présent, jour, jusqu, jusque, pas, sans, moment
# Topic 868: bienveillant, accueil, sympathique, merci, présentation, agréable, bonne, explications, bien, explication
# Topic 869: abonnements, abonnés, client, services, favorable, amélioration, compte, préférence, qualité, satisfait
# Topic 870: très, suis, je, , , , , , ,
# Topic 871: satisfaite, satisfait, suis, je, , , , , ,
# Topic 872: bonjour, merci, bien, rien, vous, pour, pas, parlez, mais, quelle
# Topic 873: meilleure, meilleurs, meilleur, sont, est, mon, ce, les, ,
# Topic 874: conseil, bon, très, , , , , , ,
# Topic 875: service, clients, client, fournisseur, personnel, bonne, top, bien, bon, pour
# Topic 876: rapide, tres, très, et, bon, bien, comprehensible, , ,
# Topic 877: bien, très, , , , , , , ,
# Topic 878: france, français, française, incompétence, puisque, tarif, lors, devaient, quittez, éviter
# Topic 879: bien, bon, suivi, accompagner, améliorer, très, , , ,
# Topic 880: client, clients, comptes, usagers, service, messagerie, entreprise, bancaires, mails, téléphoniques
# Topic 881: service, facile, efficace, satisfaisant, simple, professionnel, formidable, client, bon, rapide
# Topic 882: clientèle, clients, client, sympathique, satisfaire, portée, met, désirant, et, attention
# Topic 883: consommateurs, consommation, conseils, contactée, comparer, sollicitaient, alternatives, téléconseiller, alternative, téléconseillère
# Topic 884: clients, services, france, cliente, françaises, professionnels, compétent, entreprises, français, trustpilot
# Topic 885: écoute, recommande, besoins, besoin, compétences, adaptée, bonne, personnes, du, mes
# Topic 886: conseil, conseils, patience, satisfaite, satisfait, bons, pour, bon, souscription, détail
# Topic 887: écoute, toujours, très, et, , , , , ,
# Topic 888: remercie, merci, sympathique, accueil, parfait, charmant, merveille, satisfaite, contact, bon
# Topic 889: gaz, remercie, greenpeace, bio, proposé, informé, avantage, choisi, amélioreront, novateur
# Topic 890: paiement, payer, payés, direct, envoyée, reporté, total, transmise, taux, échanger
# Topic 891: lampiris, payeur, fiables, direct, mensualisation, harcèlent, conserve, ralenti, automatique, informaticien
# Topic 892: avons, après, bien, juste, immédiat, notre, verra, accueilli, voir, suivi
# Topic 893: oui, , , , , , , , ,
# Topic 894: faciles, tres, facile, simple, et, très, souscription, , ,
# Topic 895: rien, très, dire, bien, mon, chez, , , ,
# Topic 896: compétents, chef, responsable, délégué, recommandé, conseillé, expert, dirigé, producteur, appelé
# Topic 897: contrats, contrat, mensualités, vendre, compliqué, argent, prix, annuel, profitent, difficile
# Topic 898: paiement, rembourserais, payé, dédommagement, contrat, assurés, banque, trompé, erreur, incompétent
# Topic 899: rien, reproche, aucun, , , , , , ,
# Topic 900: rien, bien, tout, aucun, très, cela, appel, pour, dire, moment
# Topic 901: prix, profits, cher, super, top, , , , ,
# Topic 902: bien, fournisseur, bon, qualité, producteur, faire, très, de, je, travailler
# Topic 903: rapide, facile, et, , , , , , ,
# Topic 904: abonnement, téléphonique, contrats, telephone, contrat, offre, prix, téléphone, tarifaires, contact
# Topic 905: rapide, simplet, simple, et, , , , , ,
# Topic 906: électricité, électrique, puissance, utilisateur, modifier, controller, offre, numéro, puissances, client
# Topic 907: satisfaite, satisfait, satisfaction, bien, très, dans, toujours, trés, ,
# Topic 908: délai, abonnement, minutes, semaines, semaine, mail, internet, réinscrire, appeler, clients
# Topic 909: internet, app, site, mobile, application, téléphone, connexion, trouver, content, aucun
# Topic 910: étoile, rien, aucune, malheureusement, zéro, catastrophique, incompétent, ne, fuyez, malgré
# Topic 911: tarifs, tarif, baisse, économes, disparaîtront, bénéfices, diminuer, réglementés, changement, pourrait
# Topic 912: conseiller, conseillère, difficile, difficultés, conseilles, obtenir, parle, quoi, dure, ainsi
# Topic 913: rapidement, rapide, très, commerciale, fait, trop, même, loin, publicité, et
# Topic 914: contrats, pdl, frauduleuse, propriétaire, envoyant, commission, recontactera, responsable, appeller, envois
# Topic 915: voleur, voleurs, harcèlement, offres, signer, fuire, contrat, eux, arrête, signé
# Topic 916: merci, bien, ok, très, dans, , , , ,
# Topic 917: voleurs, voleur, remboursé, paye, euros, consommé, pris, reçu, 1000, taxes
# Topic 918: efficace, pratique, précis, clair, suivi, constructif, et, accueille, bien, entretien
# Topic 919: abonnements, tarifaire, consommations, taxe, compagnie, économiser, changerai, contibution, combien, augmenté
# Topic 920: appel, manque, conseille, minutes, attendre, conseil, secondes, inutile, services, volontairement
# Topic 921: 8h00, 13h00, heures, matin, 8h, 12h, arrivé, bonjour, technicien, après
# Topic 922: électricité, totalenergies, électrique, electricite, energie, énergie, contrat, parfait, satisfaite, facturation
# Topic 923: conseiller, intervention, conseils, compétent, professionnels, contact, professionnel, intervenant, engager, métier
# Topic 924: téléphonique, entretien, téléphone, minutes, attendant, appel, appelé, matin, attente, 18h
# Topic 925: contrat, remboursement, fournisseur, livraison, payais, frauduleuse, gaz, facturer, signature, refasse
# Topic 926: mensualités, prélèvements, tarifs, montant, augmentation, année, changer, change, septembre, prélèvement
# Topic 927: accueil, gentil, recommande, bien, satisfaite, bon, vous, vivement, très, professionnelle
# Topic 928: conseillère, conseiller, conseillers, attendons, lors, réception, rendez, suivi, notre, jusqu
# Topic 929: écoute, conseillé, recommande, sympathique, conseiller, bonne, explications, approche, explication, du
# Topic 930: service, clients, client, efficace, excellent, agréable, pertinentes, disponible, activer, bien
# Topic 931: harcèlement, harcèle, fraudes, coupable, payez, paiement, lettre, repression, scandaleux, mail
# Topic 932: énergie, energie, satisfaite, satisfait, satisfais, merci, recommande, ohm, prestations, expérience
# Topic 933: conseil, conseils, bons, bon, très, fiable, , , ,
# Topic 934: rapide, simple, et, en, mise, , , , ,
# Topic 935: professionnel, professionnelle, précises, clarté, entretien, bonnes, intervenante, personnel, bon, rendez
# Topic 936: retard, téléphone, attente, mobil, horaire, temps, attendre, appel, semaine, difficile
# Topic 937: payer, facturation, remboursement, facturer, facture, deblorable, rembourser, montants, fiable, 3000
# Topic 938: offre, net, prix, tarif, proposer, échange, disponibles, insistant, voulais, bloqué
# Topic 939: répondre, réponse, trouve, je, bien, su, toujours, demande, sur,
# Topic 940: payer, service, factures, fournisseur, client, gratuit, dépense, enregistrer, incompétent, compte
# Topic 976: patient, conseiller, compréhension, expérience, expliqué, précis, bonnes, bonne, bien, mot
# Topic 977: totalenergies, énergie, energie, satisfaite, satisfait, qualité, tarifs, total, fournisseurs, reste
# Topic 978: abonnement, semaines, contrat, 3ème, tard, reçu, après, échanges, cliente, échange
# Topic 979: technicien, nettoyer, nettoyé, nettoyage, manque, chaudière, entretien, intervient, contrôle, fallu

# %% [markdown]
# If more than 4 terms are needed for a topic, we can use `get_topic` and pass in the topic number. For example, `get_topic(0)` gives us the top 10 terms for topic 0 and their relative importance.

# %%
# Get top 10 terms for of the first topic
topics[0][:10]
# Out:
# [('technicienne', 0.79316366),
#  ('techniciens', 0.75618535),
#  ('technicien', 0.7526088),
#  ('professionnels', 0.69989526),
#  ('professionnel', 0.66280687),
#  ('compétent', 0.5814539),
#  ('compétents', 0.57771164),
#  ('métier', 0.55272746),
#  ('professionnalisme', 0.5466609),
#  ('competent', 0.5377156)]

# %% [markdown]
# We can visualize the top keywords using a bar chart. `top_n_topics=12` means that we will create bar charts for the top 12 topics. The length of the bar represents the score of the keyword. A longer bar means higher importance for the topic.

# %%
# Visualize top topic keywords
bertopic.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e8403fec-4289-44f7-9e61-1d7a4681fa8d" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8403fec-4289-44f7-9e61-1d7a4681fa8d")) {                    Plotly.newPlot(                        "e8403fec-4289-44f7-9e61-1d7a4681fa8d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.6628068685531616,0.6998952627182007,0.7526087760925293,0.7561853528022766,0.7931636571884155],"y":["professionnel  ","professionnels  ","technicien  ","techniciens  ","technicienne  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.6829437613487244,0.8046510219573975,0.8060548305511475,0.8077973127365112,0.8161818981170654],"y":["contact  ","t\u00e9l\u00e9phone  ","t\u00e9l\u00e9phoniques  ","telephone  ","t\u00e9l\u00e9phonique  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.6872295141220093,0.7358353137969971,0.7609976530075073,0.9104216694831848,0.9551677703857422],"y":["  ","tr\u00e8s  ","fait  ","parfait  ","bien  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.5334374904632568,0.5919966697692871,0.6266940832138062,0.6392465829849243,0.6415151357650757],"y":["pompe  ","thermostat  ","chauffage  ","chaudi\u00e8res  ","chaudi\u00e8re  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.28148353099823,0.2895925045013428,0.31121280789375305,0.44679775834083557,0.5148206353187561],"y":["contrat  ","fournisseur  ","enedis  ","eni  ","engie  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.8023421168327332,0.8023421168327332,0.8023421168327332,0.8023421168327332,0.9943599700927734],"y":["  ","  ","  ","  ","bien  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.5095747113227844,0.5284751653671265,0.5507276058197021,0.6000075936317444,0.6076503992080688],"y":["rembourser  ","rembours\u00e9  ","payer  ","remboursement  ","paiement  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.6220270395278931,0.6387220025062561,0.6710174679756165,0.6959264278411865,0.7524202466011047],"y":["\u00e9nergie  ","\u00e9nergies  ","greenwashing  ","greenpeace  ","green  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.5124921798706055,0.5451614856719971,0.5519454479217529,0.5691062211990356,0.5949625968933105],"y":["pompe  ","technicien  ","techniciens  ","chaudi\u00e8res  ","chaudi\u00e8re  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.4635705351829529,0.4738711714744568,0.48923259973526,0.4967055022716522,0.5105726718902588],"y":["malhonn\u00eates  ","incomp\u00e9tence  ","incomp\u00e9tents  ","malhonn\u00eatet\u00e9  ","escroquerie  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.8397696018218994,0.8422112464904785,0.8544772863388062,0.8547666072845459,0.9008817672729492],"y":["simplicit\u00e9  ","facile  ","f\u00e1cile  ","simplicite  ","simple  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.4685736894607544,0.4793927073478699,0.5042859315872192,0.5207946300506592,0.5393362641334534],"y":["collaboratrice  ","remerciements  ","engag\u00e9  ","contrats  ","contrat  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"erro ...

# %% [markdown]
# Another view for keyword importance is the "Term score decline per topic" chart. It's a line chart with the term rank being the x-axis and the c-TF-IDF score on the y-axis.
#
# There are a total of 31 lines, one line for each topic. Hovering over the line shows the term score information.

# %% [markdown]
# # Topic Similarities

# %% [markdown]
# In step 6, we will analyze the relationship between the topics generated by the topic model.
#
# Intertopic distance map measures the distance between topics. Similar topics are closer to each other, and very different topics are far from each other. From the visualization, we can see that there are five topic groups for all the topics. Topics with similar semantic meanings are in the same topic group.
#
# The size of the circle represents the number of documents in the topics, and larger circles mean that more reviews belong to the topic.

# %%
# Visualize intertopic distance
bertopic.visualize_topics(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="18185205-cad3-4704-8521-60b130de9f4c" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18185205-cad3-4704-8521-60b130de9f4c")) {                    Plotly.newPlot(                        "18185205-cad3-4704-8521-60b130de9f4c",                        [{"customdata":[[0,"technicienne | techniciens | technicien | professionnels | professionnel",935],[1,"t\u00e9l\u00e9phonique | telephone | t\u00e9l\u00e9phoniques | t\u00e9l\u00e9phone | contact",907],[2,"bien | parfait | fait | tr\u00e8s | ",521],[3,"chaudi\u00e8re | chaudi\u00e8res | chauffage | thermostat | pompe",501],[4,"engie | eni | enedis | fournisseur | contrat",340],[5,"bien |  |  |  | ",290],[6,"paiement | remboursement | payer | rembours\u00e9 | rembourser",267],[7,"green | greenpeace | greenwashing | \u00e9nergies | \u00e9nergie",227],[8,"chaudi\u00e8re | chaudi\u00e8res | techniciens | technicien | pompe",214],[9,"escroquerie | malhonn\u00eatet\u00e9 | incomp\u00e9tents | incomp\u00e9tence | malhonn\u00eates",187],[10,"simple | simplicite | f\u00e1cile | facile | simplicit\u00e9",174],[11,"contrat | contrats | engag\u00e9 | remerciements | collaboratrice",159],[12,"solaires | solaire | photovolta\u00efques | professionnel | conseiller",150],[13,"t\u00e9l\u00e9phonique | t\u00e9l\u00e9phoniques | t\u00e9l\u00e9phone | t\u00e9l\u00e9conseiller | telephone",144],[14,"factures | pr\u00e9l\u00e8vements | financi\u00e8re | payer | paye",140],[15,"edf | facture | banque | contrat | eur",126],[16,"edf | enr | comp\u00e9tent | professionnel | conseillerait",120],[17,"ras | le | sympa |  | ",113],[18,"convient | appr\u00e9cie | parfaitement | ilek | recommande",107],[19,"recommandee | volonte | bonneconnaissance | founiseur | marre",103],[20,"engie | satisfaits | satisfaite | satisfait | eni",99],[21,"facture | 104990331 | 104643028 | 104990890 | 104498519",95],[22,"ras | de |  |  | ",90],[23,"subscription | abonement | abonnement | abonn\u00e9e | abonner",90],[24,"inscription | inscriptions | rapide | textes | rapidit\u00e9",89],[25,"parfait |  |  |  | ",89],[26,"qualit\u00e9 | service | avantageux | good | excellent",89],[27,"attendrai | attendons | attente | espere | attendos",88],[28,"intervention | interventions | intervenant | intervenants | assistance",86],[29,"personne | rien | \u00e9couter | \u00e9coute | voix",84]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":
994,0.11482890695333481,0.9999998807907104,0.2505805194377899,0.29814407229423523,0.7374259233474731,0.10215437412261963,0.5403729677200317,0.24636344611644745],[0.42310407757759094,0.44580018520355225,0.3763681948184967,0.35519254207611084,0.34068894386291504,0.35197335481643677,0.2505805194377899,1.0000001192092896,0.49801313877105713,0.31386634707450867,0.3558333218097687,0.43709439039230347,0.4738428592681885],[0.7484434843063354,0.447266161441803,0.38959717750549316,0.7691522836685181,0.3377376198768616,0.35572242736816406,0.29814407229423523,0.49801313877105713,0.9999998211860657,0.28261828422546387,0.3405073881149292,0.549155592918396,0.4721677303314209],[0.28645196557044983,0.32593318819999695,0.11682827025651932,0.46373337507247925,0.6399163603782654,0.13921131193637848,0.7374259233474731,0.31386634707450867,0.28261828422546387,1.0000003576278687,0.13397525250911713,0.4245144724845886,0.23186075687408447] ...

# %% [markdown]
# # Topic Model In-sample Predictions

# %% [markdown]
# In step 8, we will talk about how to make in-sample predictions using the topic model.
#
# BERTopic model can output the predicted topic for each review in the dataset.
#
# Using `.topics_`, we save the predicted topics in a list and then save it as a column in the review dataset.

# %%
# Get the topic predictions
prediction = bertopic.topics_

# Save the predictions in the dataframe
df2 = pd.DataFrame(data["verbatim"], prediction)

# Take a look at the data
df2.head()
# Out:
#                                                verbatim
# -1                                                  NaN
#  146  Mauvaise expérience avec Engie ke ne recommand...
# -1                                                  NaN
#  61   J'ai écrit sur le chat engie pour avoir des ex...
#  1    Engie facture a ses clients des sommes exorbit...

# %% [markdown]
# # Topic Model Predictions on New Data

# %% [markdown]
# In this step, we will talk about how to use the BERTopic model to make predictions on new reviews.
#
# Let's say there is a new review "I like the new headphone. Its sound quality is great.", and we would like to automatically predict the topic for this review.
# * Firstly, let's decide the number of topics to include in the prediction.
#  * If we would like to assign only one topic to the document, then the number of topics should be 1.
#  * If we would like to assign multiple topics to the document, then the number of topics should be greater than 1. Here we are getting the top 3 topics that are most relevant to the new review.
# * After that, we pass the new review and the number of topics to the `find_topics` method. This gives us the topic number and the similarity value.
# * Finally, the results are printed. The top 3 similar topics for the new review are topic 1, topic 0, and topic 2. The similarities are 0.43, 0.34, and 0.30.

# %%
# New data for the review
new_review = # Write a fake review

# Find topics of the new review


# Print results

# %% [markdown]
# To verify if the assigned topics are a good fit for the new review, let's get the top keywords for the top 3 topics using the `get_topic` method.

# %%
# Print the top keywords for the top similar topics

# %% [markdown]
# We can see that topic 1 is about headsets and topic 0 is about sound quality. Both topics are a good fit for the new review. Topic 2 is about the earpiece, which is similar to the headset. From this example, we can see that the BERTopic model made good predictions on the new document.

# %% [markdown]
# # Save and Load Topic Models

# %%
# Save the topic model
topic_model.save("amz_review_topic_model")

# Load the topic model
my_model = BERTopic.load("amz_review_topic_model")

# %% [markdown]
# # References

# %% [markdown]
# * [BERTopic GitHub](https://github.com/MaartenGr/BERTopic)
# * [Documentation on BERTopic algorithms](https://maartengr.github.io/BERTopic/algorithm/algorithm.html#visual-overview)
# * [UMAP documentation](https://umap-learn.readthedocs.io/en/latest/parameters.html)
